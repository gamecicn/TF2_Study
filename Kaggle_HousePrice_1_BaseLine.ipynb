# %% [markdown]
# <a href="https://colab.research.google.com/github/gamecicn/TF2_Study/blob/Kaggle_HousePrice/Kaggle_HousePrice_1_BaseLine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First XGBoost model for Pima Indians dataset
import os
import pandas as pd
import numpy as np

from numpy import loadtxt
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
DATA_FOLDER = "/content/drive/MyDrive/DS_data/HousePrice"

TRAIN_FILE = os.path.join(DATA_FOLDER, "train.csv")
TEST_FILE  = os.path.join(DATA_FOLDER, "test.csv")

# load data
train_data = pd.read_csv(TRAIN_FILE)
test_data = pd.read_csv(TEST_FILE)

# %% [markdown]
# # EDA

# %% [markdown]
# ### Data Over view

# %%
print("Train data shape:", train_data.shape) 
print("Test  data shape:", test_data.shape)
# Out:
# Train data shape: (1460, 81)
# Test  data shape: (1459, 80)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Transformation
#
# Transform data type

# %% [markdown]
# ### Impute Missing data

# %% [markdown]
# # Build Model

# %%
# Create mini databset

MINI_COL = ["MSSubClass", "LotFrontage", "SalePrice"]

train_data_mini = train_data[MINI_COL]

# Some special preprocess for mini dataset
train_data_mini.dropna(inplace=True)

train_data_mini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSSubClass   1201 non-null   int64
#  1   LotFrontage  1201 non-null   float64
#  2   SalePrice    1201 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 37.5 KB
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_train = train_data_mini_X.iloc[:, 0:-1]
Y_train = train_data_mini_X.iloc[:, -1]
X_train.head()

# %%
model = XGBRegressor()
model.fit(X_train, Y_train)
# Out:
# [14:20:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Predict

# %%
y_pred = model.predict(test_data[MINI_COL[:-1]])

# %% [markdown]
# ### Write to submit file

# %%
answer = pd.DataFrame(data={"Id" : range(1461, 1461+len(y_pred)), 
                            "SalePrice" : y_pred})

answer.head()
# Out:
#      Id      SalePrice
# 0  1461  180285.250000
# 1  1462  186413.859375
# 2  1463  215710.421875
# 3  1464  231323.000000
# 4  1465  203309.078125

# %%
OUTPUT_PATH = "/content/drive/MyDrive/output"
OUTPUT_FILE_NAME = "kaggle_house_price_1.csv"

answer.to_csv(os.path.join(OUTPUT_PATH, OUTPUT_FILE_NAME), index=False)
